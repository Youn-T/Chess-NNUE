# %%
import cProfile
import chess
import model   
import timeit
import time

# %%
board = chess.Board()
# cProfile.run('model.minimax(board, depth=3)')

# %%
t_0 = time.perf_counter()
print(t_0)
model.minimax(board, depth=5)
t_1 = time.perf_counter()
print(t_1)
print(f"Minimax took {t_1 - t_0:.4f} seconds")
# Out:
# 8569.1613953
# 8582.9123457
# Minimax took 13.7510 seconds
