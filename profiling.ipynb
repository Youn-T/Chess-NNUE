# %%
import cProfile
import chess
import model   
import timeit
import time

# %%
board = chess.Board()
# cProfile.run('model.minimax(board, depth=3)')

# %%
t_0 = time.perf_counter()
print(t_0)
model.minimax(board, depth=6)
t_1 = time.perf_counter()
print(t_1)
print(f"Minimax took {t_1 - t_0:.4f} seconds")
# Out:
# 7403.926614
# 7479.1940944
# Minimax took 75.2675 seconds
